# %% [markdown]
# # while_statments
#
# - loops when condition is True
# - "if-loop" kör sålänge det är true

# %%
n = 0
while n < 10:
    print(f"Hello {n}")
    n += 1
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9

# %%
i = 0

while i <= 5:
    print(f"hi number {i}")
    i += 1
# Out:
# hi number 0
# hi number 1
# hi number 2
# hi number 3
# hi number 4
# hi number 5

# %% [markdown]
# first 10 sqares

# %%
i = -10
while i <= 10:
    # **2 är upphöjt till 2, alltså kvadraten av i
    square = i**2
    print(square, end="  ")
    i += 1
# Out:
# 100  81  64  49  36  25  16  9  4  1  0  1  4  9  16  25  36  49  64  81  100

# %% [markdown]
# ## Oil leakage

# %%
year = 0
birds = 80000

while birds > 8000:
    birds = birds / 2
    year += 1
    print(f"Year {year}: {birds} birds left")
# Out:
# Year 1: 40000.0 birds left
# Year 2: 20000.0 birds left
# Year 3: 10000.0 birds left
# Year 4: 5000.0 birds left

# %% [markdown]
# ## Break

# %%
import random as rnd

dice = rnd.randint(1,6)

guess = input ("guess the dice: ")

if guess == dice:
    print("You win")
else:
    print("You lose")

print(dice)    
print(guess)
# Out:
#   Cell In[25], line 9
#     print(dice)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 8
